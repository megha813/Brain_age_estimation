# %%
import os
import csv
import subprocess

import pandas as pd

# %%
base_dir = "/home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I"

output_dir = "/home/omen/Documents/Megha/ABIDE1_PREPROCESSED"

# cropped_image_folder = "/home/omen/Documents/Megha/preprocessed_ixi1/cropped"
bet_folder_loc ='/home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bet'
bias_field_corrected_loc = '/home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected'
flirt_registered__loc= '/home/omen/Documents/Megha/ABIDE1_PREPROCESSED/linear_registered'
affine_mat__loc = '/home/omen/Documents/Megha/ABIDE1_PREPROCESSED/affine'
warp_coeff_loc ='/home/omen/Documents/Megha/ABIDE1_PREPROCESSED/warp'
non_linear_loc =  '/home/omen/Documents/Megha/ABIDE1_PREPROCESSED/non_linear_registered'
# complete_preprocessed_loc = '/home/omen/Documents/Megha/ABIDE1_PREPROCESSED/completely_preprocessed'

stages = {
    "bet":        bet_folder_loc,
    "bias_field": bias_field_corrected_loc,
    "flirt":      flirt_registered__loc,
    "affine":     affine_mat__loc,
    "warp":       warp_coeff_loc,
    "non_linear": non_linear_loc
    # "final_bet":  complete_preprocessed_loc,
    # "cropped_image" : cropped_image_folder
}


config_file = "T1_2_MNI152_2mm"
FSL_STANDARD_BRAIN = '/home/omen/fsl5.0.10/data/standard/MNI152_T1_2mm.nii.gz'
FSL_STANDARD_BRAIN_MASKED = '/home/omen/fsl5.0.10/data/standard/MNI152_T1_2mm_brain.nii.gz'
f_value= 0.4

# %% [markdown]
# loading the csv for the data

# %%
file = pd.read_csv('/home/omen/Documents/Megha/ABIDE_I_relative_paths_with_age_sex.csv')
print(file.columns)
for rel_path in file['relative_path']:
    site = rel_path.split("/")[0]
    # site = os.path.basename(rel_path)
    # site = os.path.basename(rel_path).replace(".nii.gz", "")
    # t1_files = file[file['relative_path'].str.contains("T1", case=False)]
    print(site)

for rel_path in file['relative_path']:
    site = rel_path.split("/")[0]
    # print(site)
    out_fname = f"{site}.nii.gz" 
    print(out_fname)
# Out:
# Index(['subject', 'relative_path', 'age_at_scan', 'sex'], dtype='object')
# CMU_50665
# Leuven_50707
# OHSU_50160
# Yale_50577
# SDSU_50198
# NYU_51081
# Trinity_50263
# KKI_50790
# Leuven_50723
# Trinity_51140
# OHSU_50158
# Yale_50567
# KKI_50773
# SDSU_50197
# SBL_51566
# Olin_50112
# SDSU_50211
# Pitt_50030
# NYU_51122
# NYU_51067
# NYU_51096
# MaxMun_51373
# Trinity_50260
# Caltech_51490
# UM_50427
# UM_50428
# KKI_50781
# MaxMun_51360
# Yale_50565
# UM_50334
# NYU_51044
# Pitt_50044
# CMU_50656
# NYU_51084
# NYU_51153
# Caltech_51480
# NYU_51069
# Yale_50556
# NYU_51126
# USM_50441
# NYU_51151
# Pitt_50050
# UM_50370
# KKI_50814
# SDSU_50200
# SBL_51562
# UM_50391
# KKI_50778
# UM_50371
# Stanford_51182
# KKI_50819
# USM_50447
# UM_50381
# Pitt_50043
# USM_50462
# OHSU_50165
# UM_50367
# NYU_51051
# Stanford_51193
# Olin_50107
# Leuven_50726
# OHSU_50163
# Pitt_50036
# CMU_50658
# UM_50374
# Pitt_50060
# NYU_51075
# Leuven_50738
# OHSU_50166
# KKI_50777
# Yale_50568
# USM_50445
# Leuven_50699
# NYU_51093
# NYU_51098
# Olin_50114
# UCLA_51312
# Caltech_51485
# USM_50436
# UM_50377
# Caltech_51481
# Trinity_51132
# Stanford_51180
# Yale_50574
# MaxMun_51346
# Yale_50555
# CMU_50669
# NYU_51106
# UCLA_51309
# OHSU_50164
# UCLA_51251
# NYU_51131
# Stanford_51199
# USM_50438
# KKI_50813
# USM_50439
# MaxMun_51339
# Pitt_50054
# SBL_51557
# UM_50423
# Leuven_50688
# UM_50388
# UM_50357
# NYU_51048
# UM_50382
# NYU_51077
# USM_50472
# NYU_51041
# Yale_50562
# SDSU_50210
# UCLA_51274
# MaxMun_51345
# KKI_50810
# Leuven_50701
# Olin_50103
# Yale_50575
# NYU_51063
# Trinity_51142
# SDSU_50195
# MaxMun_51369
# NYU_51070
# USM_50473
# MaxMun_51342
# UM_50328
# Stanford_51191
# UCLA_51282
# UM_50353
# Leuven_50733
# Pitt_50042
# UM_50341
# UCLA_51279
# Leuven_50737
# Stanford_51181
# KKI_50786
# NYU_51053
# Caltech_51491
# MaxMun_51371
# NYU_51118
# NYU_51107
# UCLA_51255
# NYU_51099
# MaxMun_51340
# UCLA_51276
# Pitt_50052
# CMU_50666
# MaxMun_51334
# NYU_51148
# Caltech_51479
# UCLA_51273
# UM_50337
# NYU_51101
# Leuven_50698
# NYU_51068
# UCLA_51250
# UCLA_51263
# Pitt_50040
# Trinity_51136
# SDSU_50203
# OHSU_50162
# SBL_51569
# MaxMun_51370
# MaxMun_51336
# MaxMun_51372
# Leuven_50736
# Stanford_51192
# NYU_51100
# Caltech_51486
# UM_50387
# UM_50419
# Caltech_51484
# SDSU_50199
# UCLA_51308
# CMU_50659
# USM_50433
# OHSU_50169
# UCLA_51264
# Caltech_51488
# UM_50376
# UM_50415
# USM_50437
# Caltech_51493
# NYU_51083
# CMU_50657
# Olin_50111
# Olin_50113
# MaxMun_51347
# CMU_50668
# NYU_51076
# SBL_51559
# Olin_50105
# MaxMun_51357
# SBL_51568
# NYU_51128
# SBL_51570
# Leuven_50682
# Stanford_51185
# SDSU_50215
# UM_50333
# USM_50440
# USM_50455
# Leuven_50734
# NYU_51115
# NYU_51061
# UM_50369
# UM_50344
# Yale_50570
# NYU_51042
# CMU_50664
# UM_50330
# UM_50351
# USM_50446
# SDSU_50213
# USM_50463
# Caltech_51475
# UM_50417
# NYU_51124
# UCLA_51313
# UM_50329
# UM_50339
# Leuven_50685
# UM_50347
# UCLA_51303
# NYU_51060
# UCLA_51260
# Pitt_50041
# UM_50414
# NYU_51079
# NYU_51071
# Trinity_51139
# USM_50468
# Trinity_51135
# UCLA_51272
# NYU_51113
# UM_50348
# CMU_50660
# Olin_50115
# NYU_51130
# Trinity_51134
# MaxMun_51362
# Pitt_50034
# NYU_51108
# NYU_51103
# NYU_51109
# SDSU_50204
# NYU_51066
# Caltech_51478
# UM_50331
# SDSU_50201
# Pitt_50048
# MaxMun_51338
# MaxMun_51361
# USM_50432
# UM_50338
# UM_50359
# NYU_51064
# Caltech_51492
# MaxMun_51366
# UM_50380
# UM_50421
# KKI_50783
# UCLA_51311
# Olin_50109
# Yale_50552
# KKI_50775
# UM_50336
# USM_50474
# Caltech_51489
# KKI_50779
# UCLA_51259
# OHSU_50170
# NYU_51121
# NYU_51086
# UCLA_51271
# MaxMun_51359
# Yale_50576
# Stanford_51194
# NYU_51087
# UM_50363
# KKI_50822
# USM_50454
# Leuven_50706
# UCLA_51254
# Yale_50573
# USM_50442
# Leuven_50703
# Trinity_51141
# NYU_51091
# UM_50424
# Trinity_50257
# MaxMun_51332
# USM_50460
# NYU_51089
# MaxMun_51343
# MaxMun_51367
# KKI_50808
# NYU_51147
# SDSU_50208
# SDSU_50214
# Olin_50117
# Stanford_51195
# KKI_50812
# UM_50346
# USM_50435
# SDSU_50209
# NYU_51054
# UM_50385
# MaxMun_51368
# NYU_51088
# SBL_51560
# UM_50352
# Leuven_50740
# KKI_50784
# USM_50453
# UCLA_51275
# Leuven_50683
# UCLA_51305
# NYU_51082
# NYU_51155
# Leuven_50735
# SBL_51565
# Stanford_51186
# KKI_50821
# USM_50449
# NYU_51116
# UM_50349
# UM_50340
# NYU_51111
# Yale_50553
# KKI_50818
# UCLA_51256
# SDSU_50217
# Yale_50566
# USM_50466
# UM_50327
# Trinity_50267
# Pitt_50037
# UM_50368
# UM_50425
# Trinity_50262
# Pitt_50045
# MaxMun_51333
# UM_50361
# UCLA_51281
# USM_50448
# USM_50456
# USM_50461
# UM_50332
# Trinity_50268
# NYU_51125
# Pitt_50049
# NYU_51057
# NYU_51120
# NYU_51094
# SDSU_50205
# Yale_50554
# Yale_50571
# Yale_50578
# Leuven_50722
# NYU_51085
# KKI_50811
# UM_50343
# USM_50465
# USM_50470
# Stanford_51188
# Olin_50116
# MaxMun_51358
# NYU_51036
# KKI_50820
# UM_50422
# UM_50342
# UCLA_51315
# NYU_51078
# NYU_51072
# NYU_51129
# UCLA_51277
# NYU_51080
# Yale_50551
# Yale_50560
# OHSU_50161
# Caltech_51476
# MaxMun_51363
# MaxMun_51341
# Leuven_50742
# CMU_50665.nii.gz
# Leuven_50707.nii.gz
# OHSU_50160.nii.gz
# Yale_50577.nii.gz
# SDSU_50198.nii.gz
# NYU_51081.nii.gz
# Trinity_50263.nii.gz
# KKI_50790.nii.gz
# Leuven_50723.nii.gz
# Trinity_51140.nii.gz
# OHSU_50158.nii.gz
# Yale_50567.nii.gz
# KKI_50773.nii.gz
# SDSU_50197.nii.gz
# SBL_51566.nii.gz
# Olin_50112.nii.gz
# SDSU_50211.nii.gz
# Pitt_50030.nii.gz
# NYU_51122.nii.gz
# NYU_51067.nii.gz
# NYU_51096.nii.gz
# MaxMun_51373.nii.gz
# Trinity_50260.nii.gz
# Caltech_51490.nii.gz
# UM_50427.nii.gz
# UM_50428.nii.gz
# KKI_50781.nii.gz
# MaxMun_51360.nii.gz
# Yale_50565.nii.gz
# UM_50334.nii.gz
# NYU_51044.nii.gz
# Pitt_50044.nii.gz
# CMU_50656.nii.gz
# NYU_51084.nii.gz
# NYU_51153.nii.gz
# Caltech_51480.nii.gz
# NYU_51069.nii.gz
# Yale_50556.nii.gz
# NYU_51126.nii.gz
# USM_50441.nii.gz
# NYU_51151.nii.gz
# Pitt_50050.nii.gz
# UM_50370.nii.gz
# KKI_50814.nii.gz
# SDSU_50200.nii.gz
# SBL_51562.nii.gz
# UM_50391.nii.gz
# KKI_50778.nii.gz
# UM_50371.nii.gz
# Stanford_51182.nii.gz
# KKI_50819.nii.gz
# USM_50447.nii.gz
# UM_50381.nii.gz
# Pitt_50043.nii.gz
# USM_50462.nii.gz
# OHSU_50165.nii.gz
# UM_50367.nii.gz
# NYU_51051.nii.gz
# Stanford_51193.nii.gz
# Olin_50107.nii.gz
# Leuven_50726.nii.gz
# OHSU_50163.nii.gz
# Pitt_50036.nii.gz
# CMU_50658.nii.gz
# UM_50374.nii.gz
# Pitt_50060.nii.gz
# NYU_51075.nii.gz
# Leuven_50738.nii.gz
# UM_50358.nii.gz
# NYU_51149.nii.gz
# Leuven_50727.nii.gz
# Leuven_50731.nii.gz
# NYU_51114.nii.gz
# UM_50383.nii.gz
# UCLA_51304.nii.gz
# Leuven_50732.nii.gz
# UM_50345.nii.gz
# SDSU_50193.nii.gz
# NYU_51045.nii.gz
# NYU_51056.nii.gz
# Caltech_51483.nii.gz
# UM_50416.nii.gz
# Trinity_51137.nii.gz
# SDSU_50194.nii.gz
# UCLA_51261.nii.gz
# Trinity_51138.nii.gz
# Pitt_50051.nii.gz
# KKI_50789.nii.gz
# UCLA_51258.nii.gz
# MaxMun_51356.nii.gz
# Pitt_50039.nii.gz
# CMU_50663.nii.gz
# Pitt_50032.nii.gz
# Yale_50572.nii.gz
# SBL_51558.nii.gz
# MaxMun_51335.nii.gz
# UCLA_51267.nii.gz
# Caltech_51487.nii.gz
# KKI_50780.nii.gz
# NYU_51095.nii.gz
# USM_50457.nii.gz
# Pitt_50046.nii.gz
# SBL_51561.nii.gz
# Trinity_50270.nii.gz
# UM_50390.nii.gz
# UM_50379.nii.gz
# CMU_50667.nii.gz
# UM_50364.nii.gz
# NYU_51112.nii.gz
# UM_50372.nii.gz
# NYU_51104.nii.gz
# USM_50469.nii.gz
# Yale_50559.nii.gz
# Pitt_50047.nii.gz
# OHSU_50157.nii.gz
# Yale_50561.nii.gz
# Trinity_50259.nii.gz
# Trinity_50271.nii.gz
# UM_50356.nii.gz
# UM_50360.nii.gz
# NYU_51156.nii.gz
# UCLA_51314.nii.gz
# Olin_50108.nii.gz
# Yale_50558.nii.gz
# Caltech_51477.nii.gz
# MaxMun_51364.nii.gz
# NYU_51154.nii.gz
# KKI_50785.nii.gz
# USM_50471.nii.gz
# NYU_51152.nii.gz
# USM_50464.nii.gz
# Olin_50102.nii.gz
# SDSU_50196.nii.gz
# SDSU_50206.nii.gz
# Pitt_50031.nii.gz
# UM_50365.nii.gz
# Yale_50557.nii.gz
# NYU_51102.nii.gz
# UCLA_51266.nii.gz
# KKI_50774.nii.gz
# KKI_50772.nii.gz
# NYU_51058.nii.gz
# USM_50450.nii.gz
# Leuven_50709.nii.gz
# Trinity_50265.nii.gz
# SBL_51563.nii.gz
# UM_50375.nii.gz
# Pitt_50038.nii.gz
# UM_50373.nii.gz
# NYU_51065.nii.gz
# UM_50378.nii.gz
# Stanford_51197.nii.gz
# Trinity_50266.nii.gz
# NYU_51123.nii.gz
# KKI_50816.nii.gz
# Pitt_50059.nii.gz
# Stanford_51187.nii.gz
# SDSU_50202.nii.gz
# Olin_50110.nii.gz
# OHSU_50168.nii.gz
# NYU_51159.nii.gz
# UM_50362.nii.gz
# UCLA_51253.nii.gz
# Stanford_51190.nii.gz
# UM_50355.nii.gz
# NYU_51074.nii.gz
# UCLA_51268.nii.gz
# KKI_50788.nii.gz
# NYU_51090.nii.gz
# NYU_51038.nii.gz
# Stanford_51196.nii.gz
# NYU_51062.nii.gz
# NYU_51049.nii.gz
# UCLA_51280.nii.gz
# NYU_51127.nii.gz
# NYU_51047.nii.gz
# OHSU_50159.nii.gz
# USM_50452.nii.gz
# UCLA_51252.nii.gz
# UCLA_51262.nii.gz
# KKI_50787.nii.gz
# KKI_50809.nii.gz
# Trinity_50261.nii.gz
# Stanford_51189.nii.gz
# UCLA_51257.nii.gz
# SBL_51567.nii.gz
# Leuven_50710.nii.gz
# Leuven_50730.nii.gz
# SBL_51556.nii.gz
# USM_50467.nii.gz
# NYU_51146.nii.gz
# Yale_50564.nii.gz
# KKI_50776.nii.gz
# Stanford_51198.nii.gz
# UCLA_51278.nii.gz
# NYU_51110.nii.gz
# UCLA_51316.nii.gz
# USM_50451.nii.gz
# Caltech_51482.nii.gz
# KKI_50782.nii.gz
# Trinity_50269.nii.gz
# MaxMun_51365.nii.gz
# USM_50459.nii.gz
# Leuven_50741.nii.gz
# NYU_51050.nii.gz
# NYU_51097.nii.gz
# UM_50354.nii.gz
# Leuven_50724.nii.gz
# Pitt_50033.nii.gz
# USM_50443.nii.gz
# UM_50335.nii.gz
# Leuven_50728.nii.gz
# USM_50434.nii.gz
# Pitt_50058.nii.gz
# NYU_51059.nii.gz
# UCLA_51307.nii.gz
# Trinity_51133.nii.gz
# Olin_50104.nii.gz
# UM_50386.nii.gz
# NYU_51052.nii.gz
# MaxMun_51344.nii.gz
# Stanford_51183.nii.gz
# Yale_50569.nii.gz
# Leuven_50692.nii.gz
# NYU_51105.nii.gz
# NYU_51055.nii.gz
# UM_50426.nii.gz
# Olin_50106.nii.gz
# Trinity_50264.nii.gz
# USM_50458.nii.gz
# NYU_51117.nii.gz
# UM_50418.nii.gz
# NYU_51040.nii.gz
# Leuven_50687.nii.gz
# UCLA_51306.nii.gz
# USM_50444.nii.gz
# OHSU_50167.nii.gz
# SBL_51564.nii.gz
# UM_50350.nii.gz
# UCLA_51265.nii.gz
# NYU_51150.nii.gz
# Leuven_50739.nii.gz
# NYU_51073.nii.gz
# Stanford_51184.nii.gz
# UCLA_51269.nii.gz
# UM_50366.nii.gz
# NYU_51119.nii.gz
# Leuven_50691.nii.gz
# KKI_50817.nii.gz
# OHSU_50171.nii.gz
# NYU_51046.nii.gz
# Leuven_50725.nii.gz
# CMU_50661.nii.gz
# Yale_50563.nii.gz
# NYU_51039.nii.gz
# Pitt_50035.nii.gz
# OHSU_50166.nii.gz
# KKI_50777.nii.gz
# Yale_50568.nii.gz
# USM_50445.nii.gz
# Leuven_50699.nii.gz
# NYU_51093.nii.gz
# NYU_51098.nii.gz
# Olin_50114.nii.gz
# UCLA_51312.nii.gz
# Caltech_51485.nii.gz
# USM_50436.nii.gz
# UM_50377.nii.gz
# Caltech_51481.nii.gz
# Trinity_51132.nii.gz
# Stanford_51180.nii.gz
# Yale_50574.nii.gz
# MaxMun_51346.nii.gz
# Yale_50555.nii.gz
# CMU_50669.nii.gz
# NYU_51106.nii.gz
# UCLA_51309.nii.gz
# OHSU_50164.nii.gz
# UCLA_51251.nii.gz
# NYU_51131.nii.gz
# Stanford_51199.nii.gz
# USM_50438.nii.gz
# KKI_50813.nii.gz
# USM_50439.nii.gz
# MaxMun_51339.nii.gz
# Pitt_50054.nii.gz
# SBL_51557.nii.gz
# UM_50423.nii.gz
# Leuven_50688.nii.gz
# UM_50388.nii.gz
# UM_50357.nii.gz
# NYU_51048.nii.gz
# UM_50382.nii.gz
# NYU_51077.nii.gz
# USM_50472.nii.gz
# NYU_51041.nii.gz
# Yale_50562.nii.gz
# SDSU_50210.nii.gz
# UCLA_51274.nii.gz
# MaxMun_51345.nii.gz
# KKI_50810.nii.gz
# Leuven_50701.nii.gz
# Olin_50103.nii.gz
# Yale_50575.nii.gz
# NYU_51063.nii.gz
# Trinity_51142.nii.gz
# SDSU_50195.nii.gz
# MaxMun_51369.nii.gz
# NYU_51070.nii.gz
# USM_50473.nii.gz
# MaxMun_51342.nii.gz
# UM_50328.nii.gz
# Stanford_51191.nii.gz
# UCLA_51282.nii.gz
# UM_50353.nii.gz
# Leuven_50733.nii.gz
# Pitt_50042.nii.gz
# UM_50341.nii.gz
# UCLA_51279.nii.gz
# Leuven_50737.nii.gz
# Stanford_51181.nii.gz
# KKI_50786.nii.gz
# NYU_51053.nii.gz
# Caltech_51491.nii.gz
# MaxMun_51371.nii.gz
# NYU_51118.nii.gz
# NYU_51107.nii.gz
# UCLA_51255.nii.gz
# NYU_51099.nii.gz
# MaxMun_51340.nii.gz
# UCLA_51276.nii.gz
# Pitt_50052.nii.gz
# CMU_50666.nii.gz
# MaxMun_51334.nii.gz
# NYU_51148.nii.gz
# Caltech_51479.nii.gz
# UCLA_51273.nii.gz
# UM_50337.nii.gz
# NYU_51101.nii.gz
# Leuven_50698.nii.gz
# NYU_51068.nii.gz
# UCLA_51250.nii.gz
# UCLA_51263.nii.gz
# Pitt_50040.nii.gz
# Trinity_51136.nii.gz
# SDSU_50203.nii.gz
# OHSU_50162.nii.gz
# SBL_51569.nii.gz
# MaxMun_51370.nii.gz
# MaxMun_51336.nii.gz
# MaxMun_51372.nii.gz
# Leuven_50736.nii.gz
# Stanford_51192.nii.gz
# NYU_51100.nii.gz
# Caltech_51486.nii.gz
# UM_50387.nii.gz
# UM_50419.nii.gz
# Caltech_51484.nii.gz
# SDSU_50199.nii.gz
# UCLA_51308.nii.gz
# CMU_50659.nii.gz
# USM_50433.nii.gz
# OHSU_50169.nii.gz
# UCLA_51264.nii.gz
# Caltech_51488.nii.gz
# UM_50376.nii.gz
# UM_50415.nii.gz
# USM_50437.nii.gz
# Caltech_51493.nii.gz
# NYU_51083.nii.gz
# CMU_50657.nii.gz
# Olin_50111.nii.gz
# Olin_50113.nii.gz
# MaxMun_51347.nii.gz
# CMU_50668.nii.gz
# NYU_51076.nii.gz
# SBL_51559.nii.gz
# Olin_50105.nii.gz
# MaxMun_51357.nii.gz
# SBL_51568.nii.gz
# NYU_51128.nii.gz
# SBL_51570.nii.gz
# Leuven_50682.nii.gz
# Stanford_51185.nii.gz
# SDSU_50215.nii.gz
# UM_50333.nii.gz
# USM_50440.nii.gz
# USM_50455.nii.gz
# Leuven_50734.nii.gz
# NYU_51115.nii.gz
# NYU_51061.nii.gz
# UM_50369.nii.gz
# UM_50344.nii.gz
# Yale_50570.nii.gz
# NYU_51042.nii.gz
# CMU_50664.nii.gz
# UM_50330.nii.gz
# UM_50351.nii.gz
# USM_50446.nii.gz
# SDSU_50213.nii.gz
# USM_50463.nii.gz
# Caltech_51475.nii.gz
# UM_50417.nii.gz
# NYU_51124.nii.gz
# UCLA_51313.nii.gz
# UM_50329.nii.gz
# UM_50339.nii.gz
# Leuven_50685.nii.gz
# UM_50347.nii.gz
# UCLA_51303.nii.gz
# NYU_51060.nii.gz
# UCLA_51260.nii.gz
# Pitt_50041.nii.gz
# UM_50414.nii.gz
# NYU_51079.nii.gz
# NYU_51071.nii.gz
# Trinity_51139.nii.gz
# USM_50468.nii.gz
# Trinity_51135.nii.gz
# UCLA_51272.nii.gz
# NYU_51113.nii.gz
# UM_50348.nii.gz
# CMU_50660.nii.gz
# Olin_50115.nii.gz
# NYU_51130.nii.gz
# Trinity_51134.nii.gz
# MaxMun_51362.nii.gz
# Pitt_50034.nii.gz
# NYU_51108.nii.gz
# NYU_51103.nii.gz
# NYU_51109.nii.gz
# SDSU_50204.nii.gz
# NYU_51066.nii.gz
# Caltech_51478.nii.gz
# UM_50331.nii.gz
# SDSU_50201.nii.gz
# Pitt_50048.nii.gz
# MaxMun_51338.nii.gz
# MaxMun_51361.nii.gz
# USM_50432.nii.gz
# UM_50338.nii.gz
# UM_50359.nii.gz
# NYU_51064.nii.gz
# Caltech_51492.nii.gz
# MaxMun_51366.nii.gz
# UM_50380.nii.gz
# UM_50421.nii.gz
# KKI_50783.nii.gz
# UCLA_51311.nii.gz
# Olin_50109.nii.gz
# Yale_50552.nii.gz
# KKI_50775.nii.gz
# UM_50336.nii.gz
# USM_50474.nii.gz
# Caltech_51489.nii.gz
# KKI_50779.nii.gz
# UCLA_51259.nii.gz
# OHSU_50170.nii.gz
# NYU_51121.nii.gz
# NYU_51086.nii.gz
# UCLA_51271.nii.gz
# MaxMun_51359.nii.gz
# Yale_50576.nii.gz
# Stanford_51194.nii.gz
# NYU_51087.nii.gz
# UM_50363.nii.gz
# KKI_50822.nii.gz
# USM_50454.nii.gz
# Leuven_50706.nii.gz
# UCLA_51254.nii.gz
# Yale_50573.nii.gz
# USM_50442.nii.gz
# Leuven_50703.nii.gz
# Trinity_51141.nii.gz
# NYU_51091.nii.gz
# UM_50424.nii.gz
# Trinity_50257.nii.gz
# MaxMun_51332.nii.gz
# USM_50460.nii.gz
# NYU_51089.nii.gz
# MaxMun_51343.nii.gz
# MaxMun_51367.nii.gz
# KKI_50808.nii.gz
# NYU_51147.nii.gz
# SDSU_50208.nii.gz
# SDSU_50214.nii.gz
# Olin_50117.nii.gz
# Stanford_51195.nii.gz
# KKI_50812.nii.gz
# UM_50346.nii.gz
# USM_50435.nii.gz
# SDSU_50209.nii.gz
# NYU_51054.nii.gz
# UM_50385.nii.gz
# MaxMun_51368.nii.gz
# NYU_51088.nii.gz
# SBL_51560.nii.gz
# UM_50352.nii.gz
# Leuven_50740.nii.gz
# KKI_50784.nii.gz
# USM_50453.nii.gz
# UCLA_51275.nii.gz
# Leuven_50683.nii.gz
# UCLA_51305.nii.gz
# NYU_51082.nii.gz
# NYU_51155.nii.gz
# Leuven_50735.nii.gz
# SBL_51565.nii.gz
# Stanford_51186.nii.gz
# KKI_50821.nii.gz
# USM_50449.nii.gz
# NYU_51116.nii.gz
# UM_50349.nii.gz
# UM_50340.nii.gz
# NYU_51111.nii.gz
# Yale_50553.nii.gz
# KKI_50818.nii.gz
# UCLA_51256.nii.gz
# SDSU_50217.nii.gz
# Yale_50566.nii.gz
# USM_50466.nii.gz
# UM_50327.nii.gz
# Trinity_50267.nii.gz
# Pitt_50037.nii.gz
# UM_50368.nii.gz
# UM_50425.nii.gz
# Trinity_50262.nii.gz
# Pitt_50045.nii.gz
# MaxMun_51333.nii.gz
# UM_50361.nii.gz
# UCLA_51281.nii.gz
# USM_50448.nii.gz
# USM_50456.nii.gz
# USM_50461.nii.gz
# UM_50332.nii.gz
# Trinity_50268.nii.gz
# NYU_51125.nii.gz
# Pitt_50049.nii.gz
# NYU_51057.nii.gz
# NYU_51120.nii.gz
# NYU_51094.nii.gz
# SDSU_50205.nii.gz
# Yale_50554.nii.gz
# Yale_50571.nii.gz
# Yale_50578.nii.gz
# Leuven_50722.nii.gz
# NYU_51085.nii.gz
# KKI_50811.nii.gz
# UM_50343.nii.gz
# USM_50465.nii.gz
# USM_50470.nii.gz
# Stanford_51188.nii.gz
# Olin_50116.nii.gz
# MaxMun_51358.nii.gz
# NYU_51036.nii.gz
# KKI_50820.nii.gz
# UM_50422.nii.gz
# UM_50342.nii.gz
# UCLA_51315.nii.gz
# NYU_51078.nii.gz
# NYU_51072.nii.gz
# NYU_51129.nii.gz
# UCLA_51277.nii.gz
# NYU_51080.nii.gz
# Yale_50551.nii.gz
# Yale_50560.nii.gz
# OHSU_50161.nii.gz
# Caltech_51476.nii.gz
# MaxMun_51363.nii.gz
# MaxMun_51341.nii.gz
# Leuven_50742.nii.gz

# %%
# Loop through the filtered T1 file paths
for rel_path in file['relative_path']:
    site = rel_path.split("/")[0]
    out_fname = f"{site}.nii.gz"  # ABIDE_KKI_29473.nii.gz
    paths = {
            "bet":        os.path.join(stages["bet"], out_fname),
            "bias_field" : os.path.join(stages["bias_field"],site),
            "flirt":      os.path.join(stages["flirt"],out_fname),
            "affine":     os.path.join(stages["affine"], f"{site}.mat"),
            "warp":       os.path.join(stages["warp"],  out_fname),
            "non_linear": os.path.join(stages["non_linear"],out_fname)
            # "final_bet":  os.path.join(stages["final_bet"], out_fname),
            # "cropped_image": os.path.join(stages["cropped_image"],out_fname)
        }
    for stage, p in paths.items():
        if stage== "bias_field":
            os.makedirs(os.path.dirname(p), exist_ok=True)
        else:
            os.makedirs(os.path.dirname(p), exist_ok=True)
    input_image = os.path.join(base_dir, rel_path)
    print(input_image)
    
    try:
        # print("cropping image")
        # subprocess.run(["robustfov", "-i", input_image, "-r", paths["cropped_image"]], check=True)

        print(f"running bet for {input_image}")
        subprocess.run([
            "bet",
            input_image,
            paths["bet"],
            "-f", str(f_value),
            "-g", "0",
            "-R"  # robust brain center estimate
             
                ], check=True)
        if not os.path.exists(paths["bet"]):
            print(f" BET did not produce output for: {input_image}")
            continue
        print("running_bias_field_correction")
        bias_base = paths["bias_field"]  
        print("-> running FAST (bias correction), output base:", bias_base)
        subprocess.run([
            "fast",
            "-B",           # output bias corrected image
            "-t", "1",      # image type = T1
            "-o", bias_base,  # output base name
            paths["bet"]
        ],check=True)
        bias_restore = bias_base + "_restore.nii.gz"
        if not os.path.exists(bias_restore):
            print("Expected FAST output not found:", bias_restore)
            print("Listing bias_field dir for debugging:", os.listdir(os.path.dirname(bias_base)))
            continue
        print("running_linear_registeration")
        
        subprocess.run([
                    "flirt",
                    "-ref", FSL_STANDARD_BRAIN_MASKED,
                    "-in", bias_restore,
                    "-omat", paths["affine"],    #change the affine - wrt the file extension
                    "-out", paths["flirt"]
                ], check=True)
        print("running non linear registeration")
        subprocess.run([
            "fnirt",
            "--in=" + bias_restore,
            "--aff=" + paths["affine"],
            "--cout=" + paths["warp"],
            "--config=" + config_file
        ], check=True)
        print("applying the transformnation")
        subprocess.run([
            "applywarp",
            "--ref=" + FSL_STANDARD_BRAIN_MASKED,
            "--in=" + bias_restore,
            "--warp=" + paths["warp"],
            "--out=" + paths["non_linear"]
        ], check=True)
        # print("lastly applying bet again on the final non linear registered image")
        # subprocess.run([
        #     "bet",
        #     paths["non_linear"],
        #     paths["final_bet"],

        # ], check=True)
        

    except subprocess.CalledProcessError as e:
                print(f"Failed processing {input_image}: {e}")
# Out:
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/CMU_50665/CMU_50665/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/CMU_50665/CMU_50665/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/CMU_50665
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Leuven_50707/Leuven_50707/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Leuven_50707/Leuven_50707/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/Leuven_50707
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/OHSU_50160/OHSU_50160/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/OHSU_50160/OHSU_50160/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/OHSU_50160
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Yale_50577/Yale_50577/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Yale_50577/Yale_50577/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/Yale_50577
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/SDSU_50198/SDSU_50198/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/SDSU_50198/SDSU_50198/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/SDSU_50198
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/NYU_51081/NYU_51081/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/NYU_51081/NYU_51081/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/NYU_51081
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Trinity_50263/Trinity_50263/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Trinity_50263/Trinity_50263/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/Trinity_50263
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/KKI_50790/KKI_50790/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/KKI_50790/KKI_50790/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/KKI_50790
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Leuven_50723/Leuven_50723/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Leuven_50723/Leuven_50723/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/Leuven_50723
# running_linear_registeration
# running non linear registeration
# applying the transformnation
# /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/Trinity_51140/Trinity_51140/anat/NIfTI/mprage.nii.gz
# running bet for /home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/
/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/USM_50467/USM_50467/anat/NIfTI/mprage.nii.gz
# running_bias_field_correction
# -> running FAST (bias correction), output base: /home/omen/Documents/Megha/ABIDE1_PREPROCESSED/bias_field_corrected/USM_50467
# running_linear_registeration
# running non linear registeration

# %% [markdown]
# Brain extraction

# %%
input = '/home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/OHSU_50158/OHSU_50158/anat/NIfTI/mprage.nii.gz'
output = 'brain_extracted.nii.gz'
f_value= 0.4

# %%
subprocess.run([
            "bet",
            input,
            output,
            "-f", str(f_value),
            "-g", "0",
            "-R",  # robust brain center estimate
            "-m"   # save mask for inspection   
                ], check=True)
# Out:
# CompletedProcess(args=['bet', '/home/omen/Documents/Megha/ABIDE_DATA/ABIDE_I/OHSU_50158/OHSU_50158/anat/NIfTI/mprage.nii.gz', 'brain_extracted.nii.gz', '-f', '0.4', '-g', '0', '-R', '-m'], returncode=0)

# %%
import subprocess

# Define inputs and outputs
input_file = "/home/omen/Documents/Megha/FSL_PREPROCESSING/brain_extracted.nii.gz"
output_basename = "brain_bias_field"

# Construct the FSL FAST command
cmd = [
    "fast",
    "-B",           # output bias corrected image
    "-t", "1",      # image type = T1
    "-o", output_basename,  # output base name
    input_file
]

# Run the command
subprocess.run(cmd, check=True)

print("Bias field correction completed. Outputs saved with prefix:", output_basename)
# Out:
# Bias field correction completed. Outputs saved with prefix: brain_bias_field

# %%
config_file = "T1_2_MNI152_2mm"
FSL_STANDARD_BRAIN = '/home/omen/fsl5.0.10/data/standard/MNI152_T1_2mm.nii.gz'
FSL_STANDARD_BRAIN_MASKED = '/home/omen/fsl5.0.10/data/standard/MNI152_T1_2mm_brain.nii.gz'

# %%
input='/home/omen/Documents/Megha/FSL_PREPROCESSING/brain_bias_field_restore.nii.gz'
affine = 'affine.mat'
out = 'linearly_registered.nii.gz'

# %%
subprocess.run([
                    "flirt",
                    "-ref", FSL_STANDARD_BRAIN_MASKED,
                    "-in", input,
                    "-omat",affine ,    #change the affine - wrt the file extension
                    "-out", out
                ], check=True)
# Out:
# CompletedProcess(args=['flirt', '-ref', '/home/omen/fsl5.0.10/data/standard/MNI152_T1_2mm_brain.nii.gz', '-in', '/home/omen/Documents/Megha/FSL_PREPROCESSING/brain_bias_field_restore.nii.gz', '-omat', 'affine.mat', '-out', 'linearly_registered.nii.gz'], returncode=0)

# %%
input = '/home/omen/Documents/Megha/FSL_PREPROCESSING/brain_bias_field_restore.nii.gz'
affine = '/home/omen/Documents/Megha/FSL_PREPROCESSING/affine.mat'
warp = 'warp.nii.gz'
output = 'non_linear.nii.gz'

# %%
subprocess.run([
            "fnirt",
            "--in=" + input,
            "--aff=" + affine,
            "--cout=" + warp,
            "--config=" + config_file
        ], check=True)
print("applying the transformnation")
subprocess.run([
    "applywarp",
    "--ref=" + FSL_STANDARD_BRAIN_MASKED,
    "--in=" + input,
    "--warp=" + warp,
    "--out=" +output
], check=True)
# Out:
# applying the transformnation
# CompletedProcess(args=['applywarp', '--ref=/home/omen/fsl5.0.10/data/standard/MNI152_T1_2mm_brain.nii.gz', '--in=/home/omen/Documents/Megha/FSL_PREPROCESSING/brain_bias_field_restore.nii.gz', '--warp=warp.nii.gz', '--out=non_linear.nii.gz'], returncode=0)
